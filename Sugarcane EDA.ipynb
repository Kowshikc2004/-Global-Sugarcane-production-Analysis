# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('List of Countries by Sugarcane Production.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df.shape
# Out:
# (103, 7)

# %%
df['Production (Tons)']=df['Production (Tons)'].str.replace(".","")

# %%
df['Production per Person (Kg)']=df['Production per Person (Kg)'].str.replace('.',"").str.replace(',','.')
df['Acreage (Hectare)']=df['Acreage (Hectare)'].str.replace('.',"")
df['Yield (Kg / Hectare)']=df['Yield (Kg / Hectare)'].str.replace('.',"").str.replace(',','.')

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                   3668.531          10226205              75167.5
# 1                     260721           4950000              70393.5
# 2                      88287           1675215              73459.1
# 3                   1264.303           1336575              65442.2
# 4                     324219           1130820                57879

# %%
df[df['Acreage (Hectare)'].isna()]
# Out:
#     Unnamed: 0   Country Continent Production (Tons)  \
# 99          99  Djibouti    Africa                53
#
#    Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 99                         51               NaN                  NaN

# %%
df.dropna().reset_index()
# Out:
#      index  Unnamed: 0    Country      Continent Production (Tons)  \
# 0        0           0     Brazil  South America         768678382
# 1        1           1      India           Asia         348448000
# 2        2           2      China           Asia         123059739
# 3        3           3   Thailand           Asia          87468496
# 4        4           4   Pakistan           Asia          65450704
# ..     ...         ...        ...            ...               ...
# 97      97          97      Spain         Europe               394
# 98      98          98    Lebanon           Asia                97
# 99     100         100  Singapore           Asia                50
# 100    101         101      Samoa        Oceania                12
# 101    102         102      Syria           Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                     3668.531          10226205              75167.5
# ...

# %%
df.drop(["index", "Unnamed: 0"], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 df.drop(["index", "Unnamed: 0"], axis = 1, inplace = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                     int64
# Country                       object
# Continent                     object
# Production (Tons)             object
# Production per Person (Kg)    object
# Acreage (Hectare)             object
# Yield (Kg / Hectare)          object
# dtype: object

# %%
df['Production (Tons)']=df['Production (Tons)'].astype(float)
df['Production per Person (Kg)']=df['Production per Person (Kg)'].astype(float)
df['Acreage (Hectare)']=df['Acreage (Hectare)'].astype(float)
df['Yield (Kg / Hectare)']=df['Yield (Kg / Hectare)'].astype(float)

# %%
df.dtypes
# Out:
# Unnamed: 0                      int64
# Country                        object
# Continent                      object
# Production (Tons)             float64
# Production per Person (Kg)    float64
# Acreage (Hectare)             float64
# Yield (Kg / Hectare)          float64
# dtype: object

# %%
df.nunique()
# Out:
# Unnamed: 0                    103
# Country                       103
# Continent                       6
# Production (Tons)             103
# Production per Person (Kg)    102
# Acreage (Hectare)             101
# Yield (Kg / Hectare)          102
# dtype: int64

# %% [markdown]
# ## Univaraiant analysis

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent  Production (Tons)  \
# 0           0    Brazil  South America        768678382.0
# 1           1     India           Asia        348448000.0
# 2           2     China           Asia        123059739.0
# 3           3  Thailand           Asia         87468496.0
# 4           4  Pakistan           Asia         65450704.0
#
#    Production per Person (Kg)  Acreage (Hectare)  Yield (Kg / Hectare)
# 0                    3668.531         10226205.0               75167.5
# 1                  260721.000          4950000.0               70393.5
# 2                   88287.000          1675215.0               73459.1
# 3                    1264.303          1336575.0               65442.2
# 4                  324219.000          1130820.0               57879.0

# %%
df["Continent"].value_counts()
# Out:
# Continent
# Africa           39
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %% [markdown]
# ## How many countries produce form each continent

# %%
df["Continent"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Continent'>

# %%
plt.figure(figsize=(10,10))

# %%
plt.subplot(2,2,1)
sns.distplot(df['Production (Tons)'])
plt.subplot(2,2,2)
sns.distplot(df['Production per Person (Kg)'])
plt.subplot(2,2,3)
sns.distplot(df['Acreage (Hectare)'])
plt.subplot(2,2,4)
sns.distplot(df['Yield (Kg / Hectare)'])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11608\2079113771.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Production (Tons)'])
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11608\2079113771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# ...

# %% [markdown]
# ## finding outliers

# %%
plt.subplot(2,2,1)
sns.boxplot(df['Production (Tons)'])
plt.subplot(2,2,2)
sns.boxplot(df['Production per Person (Kg)'])
plt.subplot(2,2,3)
sns.boxplot(df['Acreage (Hectare)'])
plt.subplot(2,2,4)
sns.boxplot(df['Yield (Kg / Hectare)'])
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#        Unnamed: 0  Production (Tons)  Production per Person (Kg)  \
# count  103.000000       1.030000e+02                  103.000000
# mean    51.000000       1.832407e+07               111856.305311
# std     29.877528       8.379760e+07               176134.928689
# min      0.000000       1.000000e+00                    0.000000
# 25%     25.500000       4.298850e+04                 3364.869000
# 50%     51.000000       1.422432e+06                25481.000000
# 75%     76.500000       6.145648e+06               144004.500000
# max    102.000000       7.686784e+08               951087.000000
#
#        Acreage (Hectare)  Yield (Kg / Hectare)
# count       1.020000e+02            102.000000
# mean        2.498981e+05          52628.078431
# std         1.137003e+06          30504.676683
# min         0.000000e+00             10.000000
# 25%         1.104000e+03          29072.025000
# 50%         1.655800e+04          54108.950000
# 75%         8.047400e+04          73282.700000
# ...

# %% [markdown]
# ## bivarient analysis

# %%
df_new=df[["Country","Production (Tons)"]].set_index("Country")

# %%
df_new
# Out:
#            Production (Tons)
# Country
# Brazil           768678382.0
# India            348448000.0
# China            123059739.0
# Thailand          87468496.0
# Pakistan          65450704.0
# ...                      ...
# Lebanon                 97.0
# Djibouti                53.0
# Singapore               50.0
# Samoa                   12.0
# Syria                    1.0
#
# [103 rows x 1 columns]

# %%
df_new["Production (Tons)_precentage"]=df_new["Production (Tons)"]*100/df_new["Production (Tons)"].sum()

# %%
df_new
# Out:
#            Production (Tons)  Production (Tons)_precentage
# Country
# Brazil           768678382.0                  4.072728e+01
# India            348448000.0                  1.846200e+01
# China            123059739.0                  6.520138e+00
# Thailand          87468496.0                  4.634389e+00
# Pakistan          65450704.0                  3.467809e+00
# ...                      ...                           ...
# Lebanon                 97.0                  5.139401e-06
# Djibouti                53.0                  2.808126e-06
# Singapore               50.0                  2.649176e-06
# Samoa                   12.0                  6.358022e-07
# Syria                    1.0                  5.298352e-08
#
# [103 rows x 2 columns]

# %%
df_new["Production (Tons)_precentage"].plot(kind="pie",autopct='2%f')
# Out:
# <Axes: ylabel='Production (Tons)_precentage'>

# %%
df_new["Production (Tons)"].plot(kind='bar')
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# ## which country produces more sugarcane

# %%
df_new["Production (Tons)"].head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Country'>

# %%
ax=sns.barplot(data=df.head(10),x='Country',y="Production (Tons)")

# %%
ax=sns.barplot(data=df.head(10),x='Country',y="Production (Tons)")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()

# %% [markdown]
# ## which country has more land allocated for sugarcane production

# %%
ax=sns.barplot(data=df.head(10),x='Country',y="Acreage (Hectare)")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()

# %% [markdown]
# ## top 10 countries in allocating land in sugarcane production

# %%
df_acr=df.sort_values("Acreage (Hectare)",ascending=False)
ax=sns.barplot(data=df_acr.head(10),x='Country',y="Acreage (Hectare)")
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()

# %% [markdown]
# ## which country has hihgtest yield(kg/Hectare)

# %%
df.head(10)
# Out:
#    Unnamed: 0                   Country      Continent  Production (Tons)  \
# 0           0                    Brazil  South America        768678382.0
# 1           1                     India           Asia        348448000.0
# 2           2                     China           Asia        123059739.0
# 3           3                  Thailand           Asia         87468496.0
# 4           4                  Pakistan           Asia         65450704.0
# 5           5                    Mexico  North America         56446821.0
# 6           6                  Colombia  South America         36951213.0
# 7           7                 Australia        Oceania         34403004.0
# 8           8                 Guatemala  North America         33533403.0
# 9           9  United States of America  North America         29926210.0
#
#    Production per Person (Kg)  Acreage (Hectare)  Yield (Kg / Hectare)
# 0                    3668.531         10226205.0               75167.5
# ...

# %%
df_yld=df.sort_values('Yield (Kg / Hectare)', ascending=False)

# %%
df_yld
# Out:
#      Unnamed: 0              Country      Continent  Production (Tons)  \
# 8             8            Guatemala  North America         33533403.0
# 57           57              Senegal         Africa           696992.0
# 15           15                Egypt         Africa         15760418.0
# 18           18                 Peru  South America          9832526.0
# 40           40               Malawi         Africa          2915406.0
# ..          ...                  ...            ...                ...
# 55           55  Trinidad and Tobago  North America              810.0
# 100         100            Singapore           Asia               50.0
# 87           87                 Iraq           Asia             1167.0
# 96           96                Yemen           Asia              500.0
# 99           99             Djibouti         Africa               53.0
#
#      Production per Person (Kg)  Acreage (Hectare)  Yield (Kg / Hectare)
# ...

# %%
ax=sns.barplot(data=df_yld.head(10),x='Country',y='Yield (Kg / Hectare)')
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.show()

# %% [markdown]
# ## which country has the highest production

# %% [markdown]
# ## correlation

# %%
df=pd.read_csv('List of Countries by Sugarcane Production.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df=pd.read_csv('List of Countries by Sugarcane Production.csv')
#
# NameError: name 'pd' is not defined

# %%
df['Production (Tons)']=df['Production (Tons)'].str.replace(".","")
df['Production per Person (Kg)']=df['Production per Person (Kg)'].str.replace('.',"").str.replace(',','.')
df['Acreage (Hectare)']=df['Acreage (Hectare)'].str.replace('.',"")
df['Yield (Kg / Hectare)']=df['Yield (Kg / Hectare)'].str.replace('.',"").str.replace(',','.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df['Production (Tons)']=df['Production (Tons)'].str.replace(".","")
#       2 df['Production per Person (Kg)']=df['Production per Person (Kg)'].str.replace('.',"").str.replace(',','.')
#       3 df['Acreage (Hectare)']=df['Acreage (Hectare)'].str.replace('.',"")
#
# NameError: name 'df' is not defined

# %%
df_1=df.copy()

# %%
df_1.drop(['Country','Continent'],axis=1,inplace=True)

# %%
df_1['Production (Tons)']=df_1['Production (Tons)'].astype(float)
df_1['Production per Person (Kg)']=df_1['Production per Person (Kg)'].astype(float)
df_1['Acreage (Hectare)']=df_1['Acreage (Hectare)'].astype(float)
df_1['Yield (Kg / Hectare)']=df_1['Yield (Kg / Hectare)'].astype(float)

# %%
df_1.dtypes
# Out:
# Unnamed: 0                      int64
# Production (Tons)             float64
# Production per Person (Kg)    float64
# Acreage (Hectare)             float64
# Yield (Kg / Hectare)          float64
# dtype: object

# %%
df_1.corr()
# Out:
#                             Unnamed: 0  Production (Tons)  \
# Unnamed: 0                    1.000000          -0.340808
# Production (Tons)            -0.340808           1.000000
# Production per Person (Kg)   -0.376831           0.016341
# Acreage (Hectare)            -0.338820           0.997550
# Yield (Kg / Hectare)         -0.475832           0.132812
#
#                             Production per Person (Kg)  Acreage (Hectare)  \
# Unnamed: 0                                   -0.376831          -0.338820
# Production (Tons)                             0.016341           0.997550
# Production per Person (Kg)                    1.000000           0.012557
# Acreage (Hectare)                             0.012557           1.000000
# Yield (Kg / Hectare)                          0.017999           0.113433
#
#                             Yield (Kg / Hectare)
# Unnamed: 0                             -0.475832
# Production (Tons)                       0.132812
# ...

# %%
sns.heatmap(df_1.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(df_1.corr(),annot=True,cmap="Greens")
# Out:
# <Axes: >

# %% [markdown]
# ## Do countries with large land produce more sugarcane?

# %%
sns.scatterplot(data=df_1,x="Acreage (Hectare)",y="Production (Tons)",)
# Out:
# <Axes: xlabel='Acreage (Hectare)', ylabel='Production (Tons)'>

# %% [markdown]
# ## do countries which yelid more sugarcane per hectare produces more sugarcane?

# %%
sns.scatterplot(data=df_1,x="Yield (Kg / Hectare)",y="Production (Tons)")
# Out:
# <Axes: xlabel='Yield (Kg / Hectare)', ylabel='Production (Tons)'>

# %% [markdown]
# ## Analysis for continent

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('List of Countries by Sugarcane Production.csv')

# %%
df
# Out:
#      Unnamed: 0    Country      Continent Production (Tons)  \
# 0             0     Brazil  South America       768.678.382
# 1             1      India           Asia       348.448.000
# 2             2      China           Asia       123.059.739
# 3             3   Thailand           Asia        87.468.496
# 4             4   Pakistan           Asia        65.450.704
# ..          ...        ...            ...               ...
# 98           98    Lebanon           Asia                97
# 99           99   Djibouti         Africa                53
# 100         100  Singapore           Asia                50
# 101         101      Samoa        Oceania                12
# 102         102      Syria           Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                    3.668,531        10.226.205             75.167,5
# 1                       260721         4.950.000             70.393,5
# ...

# %%
df['Production (Tons)']=df['Production (Tons)'].str.replace(".","")
df['Production per Person (Kg)']=df['Production per Person (Kg)'].str.replace('.',"").str.replace(',','.')
df['Acreage (Hectare)']=df['Acreage (Hectare)'].str.replace('.',"")
df['Yield (Kg / Hectare)']=df['Yield (Kg / Hectare)'].str.replace('.',"").str.replace(',','.')

# %%
df_continent=df.groupby("Continent").sum()

# %%
df_continent.dtypes
# Out:
# Unnamed: 0                     int64
# Country                       object
# Production (Tons)             object
# Production per Person (Kg)    object
# Acreage (Hectare)             object
# Yield (Kg / Hectare)          object
# dtype: object

# %%
df_continent['Production (Tons)']=df_continent['Production (Tons)'].astype(float)
df_continent['Production per Person (Kg)']=df_continent['Production per Person (Kg)'].astype(float)
df_continent['Acreage (Hectare)']=df_continent['Acreage (Hectare)'].astype(float)
df_continent['Yield (Kg / Hectare)']=df_continent['Yield (Kg / Hectare)'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 df_continent['Production (Tons)']=df_continent['Production (Tons)'].astype(float)
# ----> 2 df_continent['Production per Person (Kg)']=df_continent['Production per Person (Kg)'].astype(float)
#       3 df_continent['Acreage (Hectare)']=df_continent['Acreage (Hectare)'].astype(float)
#       4 df_continent['Yield (Kg / Hectare)']=df_continent['Yield (Kg / Hectare)'].astype(float)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
# ...

# %%
df_continent.dtypes

# %%
df_continent=df.groupby("Continent").sum()

# %%
df_continent.drop(['Country','Unnamed: 0'],axis=1,inplace=True)

# %%
df_continent
